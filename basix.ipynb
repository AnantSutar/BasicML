# %% [markdown]
# ## Datatypes in Python

# %%
'''
Text Type:	str
Numeric Types:	int, float, complex
Sequence Types:	list, tuple, range
Mapping Type:	dict
Set Types:	set, frozenset
Boolean Type:	bool
Binary Types:	bytes, bytearray, memoryview
'''
# Out:
# '\nText Type:\tstr\nNumeric Types:\tint, float, complex\nSequence Types:\tlist, tuple, range\nMapping Type:\tdict\nSet Types:\tset, frozenset\nBoolean Type:\tbool\nBinary Types:\tbytes, bytearray, memoryview\n'

# %% [markdown]
# ## use shift + tab for more info
# ### print[shift+tab]

# %%
first_name = "Anant"
last_name = "Sutar"

# %%
print("My first name is {} and last name is {}" .format(first_name,last_name))
# Out:
# My first name is Anant and last name is Sutar

# %%
print("My first name is {first} and last name is {last}" .format(first = first_name,last = last_name))
# Out:
# My first name is Anant and last name is Sutar

# %%
type(['1','2'])
# Out:
# list

# %%
name = "Anant Sutar"
# name. check for conditions

# %% [markdown]
# ### list

# %%
type([])
# Out:
# list

# %%
lst = ["A","B",1,2,3]

# %%
type(lst)
# Out:
# list

# %% [markdown]
# ### append,insert,extend

# %%
lst.append("Anant")

# %%
lst
# Out:
# ['A', 'B', 1, 2, 3, 'Anant']

# %%
#indexing
lst[1]
# Out:
# 'B'

# %%
lst[:-2]
# Out:
# ['A', 'B', 1, 2]

# %%
lst.append([4,5])
lst
# Out:
# ['A', 'B', 1, 2, 3, 'Anant', [4, 5], [4, 5]]

# %%
#appending 2 elements will give you nested list
#hence use extend to do the same

# %%
lst.insert(1,"jj")

# %%
lst.extend([8,9])
print(lst)
# Out:
# ['A', 'jj', 'B', 1, 2, 3, 'Anant', [4, 5], [4, 5], 8, 9]

# %% [markdown]
# ### oprns that we can perform

# %%
lists = [1,2,3]

# %%
sum(lists)
# Out:
# 6

# %%
lists.pop()
# Out:
# 3

# %%
lists
# Out:
# [1, 2]

# %%
lists.extend([4,5,6])

# %%
lists.pop(2)
# Out:
# 4

# %%
lists.index(5,0,5)
# Out:
# 2

# %%
sets = set()
#OR
setss = {"a","b","c"}

# %%
type(setss)
# Out:
# set
